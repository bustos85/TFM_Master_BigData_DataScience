# %% [markdown]
# ### Ejemplo de uso de Spark Streaming con Kafka y direct Stream.

# %%
# imports necesarios
# Spark Streaming
from pyspark.streaming import StreamingContext  
# Kafka
from pyspark.streaming.kafka import KafkaUtils
from pyspark import SparkContext
from pyspark import SparkConf
from pyspark.sql import SQLContext
from pyspark.sql.functions import split

import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

import json
import string
import re
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/josemanuel/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# #### Funciones necesarias para la prueba.

# %%
# función para sacar el texto de cada tweet
def returnText(x):
    try:
        return x['text']
    except:
        return ""


# función que se le pasa el texto del tweet y las palabras a eliminar del mismo (stopwords) porque no tengan
# relevancia en el lenguaje para hacer el análisis de sentimiento.
def eliminar_stopwords(texto, palabras_eliminar):
    tok = nltk.tokenize
    palabras = tok.word_tokenize(texto)
        
    palabras_salida = []
        
    for palabra in palabras:
        if palabra not in palabras_eliminar:
            palabras_salida.append(palabra)
        
    salida = ""
    for i in range(len(palabras_salida)):
        if palabras_salida[i] in string.punctuation:
            salida = salida.strip()+palabras_salida[i] + " "
        else:
            salida += palabras_salida[i] + " "

    return salida


# función para reemplazar/eliminar emojis
def handle_emojis(tweet):
    emoji_pattern = re.compile(u'['u'\U0001F300-\U0001F64F'u'\U0001F680-\U0001F6FF'u'\
                               \u2600-\u26FF\u2700-\u27BF]+', re.UNICODE)
 
    tweet = emoji_pattern.sub(r' ', tweet)

    return tweet


# función para realizar toda la limpieza y preprocesado de los textos de los tweets
def preprocesado_texto(tweet):
    processed_tweet = []
 
    # remover todos los espacios al principio y al final del tweet
    tweet = re.sub('  +', ' ', tweet).strip()
    # remover las urls
    tweet = re.sub(r'http\S+', '', tweet)
    # remover los números
    translator = str.maketrans(dict.fromkeys("0123456789"))
    tweet = tweet.translate(translator)    
    # remover los @usuario
    tweet = re.sub(r'@[\S]+', ' ', tweet)
    # remover los #hashtags
    tweet = re.sub(r'#(\S+)', r' \1 ', tweet)
    # remover RT (retweet)
    tweet = re.sub(r'\bRT\b', '', tweet)
    # reemplazar .. o más con un espacio
    tweet = re.sub(r'\.{2,}', ' ', tweet)
    # remover espacios sobrantes
    tweet = tweet.strip('"\'')
    # reemplazar múltiples espacios con un sólo espacio
    tweet = re.sub(r'\s+', ' ', tweet)
    # pasar todo a minúscula
    tweet = tweet.lower()
    # remover signos de puntuación
    translator = str.maketrans(dict.fromkeys(string.punctuation + "'\"¿?¡!,.():;´’-"))
    tweet = tweet.translate(translator)
    # convertir la repetición de una letra más de 2 veces a 1
    # biennnnn --> bien
    tweet = re.sub(r'(.)\1+', r'\1\1', tweet)
    # remover - & '
    tweet = re.sub(r'(-|\')', '', tweet) 
    # eliminar acentos
    tweet = tweet.translate(str.maketrans('áàéèíìóòúùü','aaeeiioouuu'))
    # reemplazar emojis
    tweet = handle_emojis(tweet)
    tweet = re.sub("[^A-Za-z0-9]+$",'',tweet)
    tweet = re.sub("^[^A-Za-z0-9]+",'',tweet)
    tweet = re.sub("[\$*&!?///\º\'\’\‘\|()%/\"{}@;:+\[\]\–\”\…\“\】\【=]",'',tweet)

    # remover stopwords
    spanish_stopwords = stopwords.words('spanish')
    tweet = eliminar_stopwords(tweet, spanish_stopwords)
    
    words = tweet.split()

    for word in words:
        processed_tweet.append(word)        
            
    return ' '.join(processed_tweet)

# %% [markdown]
# #### Creamos una función donde obtenemos los datos desde Kafka y mostramos por pantalla cada x tiempo algo de información de los datos obtenidos en cada batch por Spark Streaming.

# %%
def createContext():
    conf = (SparkSession\
          .builder\
          .appName("twitter")\
          .master("spark://MacBook-Pro-de-Jose.local:7077")\
          .config("spark.io.compression.codec", "snappy")\
          .getOrCreate())
    
    sc = SparkContext.getOrCreate(conf=conf)
    sc.setLogLevel("WARN")
 
    ssc = StreamingContext(sc, 30)
    ssc.checkpoint("checkpoint")
    
    # topic del que recoger los datos en español
    topic = "TopicSpanish"
    # conexión con kafka
    fromOffset=None
    opts = { "metadata.broker.list": "localhost:9092",
         "auto.offset.reset" : 'largest' }
    directKafkaStream = KafkaUtils.createDirectStream( ssc, [topic], opts, fromOffsets=fromOffset )

    # extraer tweets cogiendo directamente el texto que será el atributo a analizar
    tweets_texto = directKafkaStream.map(lambda v: json.loads(v[1])).map(returnText)
    
    # número de tweets por batch
    count_batch = directKafkaStream.count().map(lambda x:('Tweets del batch: %s' % x))

    # recuento por ventana de tiempo
    count_window = directKafkaStream.countByWindow(30,30)\
        .map(lambda x:('Tweets total (medio minuto rolling): %s' % x))
    
    # obtenemos cada texto dividido en palabras y le hacemos las transformaciones necesarias 
    # para eliminar @usuario, RT, urls, y palabras que no son relevantes para el análisis
    texto_procesado = tweets_texto.map(lambda row: (preprocesado_texto(row)))
    tokens = texto_procesado.map(lambda row: (word_tokenize(row)))
    
    # palabras más repetidas
    words = texto_procesado.flatMap(lambda tweet:tweet.split(" ")).countByValue()\
        .transform(lambda rdd:rdd.sortBy(lambda x:-x[1]))
    
    # sacar por pantalla todos los procesamientos realizados
    count_batch.pprint(5)
    count_window.pprint(5)
    tweets_texto.pprint(5)
    texto_procesado.pprint(5)
    tokens.pprint(5)
    words.pprint(5)
    
    return ssc

# %%
# lanzamos el proceso en streaming para recoger los tweets y hacerles el preprocesado y ciertos cálculos
ssc = createContext()
ssc.start()
ssc.awaitTerminationOrTimeout(120)
ssc.stop(stopGraceFully = True)

print("!!!!!!!!!!!!!!!!!!!!STOPPED!!!!!!!!!!!!!!!!!!!!")
# Out:
# -------------------------------------------
# Time: 2019-08-15 15:03:30
# -------------------------------------------
# Tweets del batch: 78
#
# -------------------------------------------
# Time: 2019-08-15 15:03:30
# -------------------------------------------
# Tweets total (medio minuto rolling): 78
#
# -------------------------------------------
# Time: 2019-08-15 15:03:30
# -------------------------------------------
# Me tienen q poner la vacuna de los 16 lpm
# RT @escorpio_hn: Los #Escorpio suelen ser personas alternativas, se suelen alejar de modas o de cosas que hace todo el mundo. Les gusta ser…
# RT @laraizaurieta: Mi ex se burla de mi porque trabajo en Mc Donalds
#
# Gano más que el
# Vivo sola
# Mantengo como puedo a mi bebé
# No dependo d…
# RT @2RADl0: #AnabelQuevedo #14Ago #53Dias
#
# ¿ Dónde está Anabel Quevedo ?
#
# https://t.co/gz5fCli3Fi
# @LeyvaJulia @imagenZea @ImagenTVMex Igualmente Julia! Excelente día.
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:03:30
# -------------------------------------------
# q poner vacuna lpm
# escorpio suelen ser personas alternativas suelen alejar modas cosas hace mundo gusta ser
# ex burla trabajo mc donalds gano mas vivo sola mantengo puedo bebe dependo d
# anabelquevedo ago dias anabel quevedo
# igualmente julia excelente dia
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:03:30
# -------------------------------------------
# ['q', 'poner', 'vacuna', 'lpm']
# ['escorpio', 'suelen', 'ser', 'personas', 'alternativas', 'suelen', 'alejar', 'modas', 'cosas', 'hace', 'mundo', 'gusta', 'ser']
# ['ex', 'burla', 'trabajo', 'mc', 'donalds', 'gano', 'mas', 'vivo', 'sola', 'mantengo', 'puedo', 'bebe', 'dependo', 'd']
# ['anabelquevedo', 'ago', 'dias', 'anabel', 'quevedo']
# ['igualmente', 'julia', 'excelente', 'dia']
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:03:30
# -------------------------------------------
# ('mas', 6)
# ('si', 6)
# ('gente', 4)
# ('tener', 4)
# ('años', 4)
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:04:00
# -------------------------------------------
# Tweets del batch: 97
#
# -------------------------------------------
# Time: 2019-08-15 15:04:00
# -------------------------------------------
# Tweets total (medio minuto rolling): 97
#
# -------------------------------------------
# Time: 2019-08-15 15:04:00
# -------------------------------------------
# Castra y asesina a su yerno por no pagar la manutención de sus hijos https://t.co/a2jkxzpyJf
# Para que tu unción sea real algo debe de morir en ty @PastorVladimir @EsmeraldadeRiva @00Zavala @AMCompaz
# RT @MissLadrillos: Para que el próximo informe de alconadamon, el cels y amnesty sobre fake news, ah no cierto: https://t.co/WfD5Krf8PW
# RT @Ozuna_Pr: Yo X Ti @rosaliavt https://t.co/l9h2v6RMcJ
# Ya me he encargado yo de tener a las mejores personas a mí lado
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:04:00
# -------------------------------------------
# castra asesina yerno pagar manutencion hijos
# uncion real debe morir ty
# proximo informe alconadamon cels amnesty fake news ah cierto
# x
# encargado tener mejores personas lado
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:04:00
# -------------------------------------------
# ['castra', 'asesina', 'yerno', 'pagar', 'manutencion', 'hijos']
# ['uncion', 'real', 'debe', 'morir', 'ty']
# ['proximo', 'informe', 'alconadamon', 'cels', 'amnesty', 'fake', 'news', 'ah', 'cierto']
# ['x']
# ['encargado', 'tener', 'mejores', 'personas', 'lado']
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:04:00
# -------------------------------------------
# ('mas', 8)
# ('dias', 6)
# ('si', 5)
# ('atrevete', 5)
# ('hacer', 4)
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:04:30
# -------------------------------------------
# Tweets del batch: 106
#
# -------------------------------------------
# Time: 2019-08-15 15:04:30
# -------------------------------------------
# Tweets total (medio minuto rolling): 106
#
# -------------------------------------------
# Time: 2019-08-15 15:04:30
# -------------------------------------------
# RT @MelukLeCuenta: En Medellín inauguran un túnel. En Bogotá, un semáforo... El chiste se cuenta solo.
# RT @IKahid: No es amor a la bebida, es desprecio a la sobriedad.
# RT @RAEinforma: Consultas de la semana | A comienzo de enunciado, ¿se escribe «Ll» o «LL»?
#
# Si una palabra que empieza con «ll» se escribe…
# Me dijeron que soy un sol, y no puedo estar más en desacuerdo):.
# RT @hijadelvih: No se comparten, no se enseñan y se borran una vez se termina la relación https://t.co/WY2eC3omZ8
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:04:30
# -------------------------------------------
# medellin inauguran tunel bogota semaforo chiste cuenta solo
# amor bebida desprecio sobriedad
# consultas semana comienzo enunciado escribe « ll » « ll » si palabra empieza « ll » escribe
# dijeron sol puedo mas desacuerdo
# comparten enseñan borran vez termina relacion
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:04:30
# -------------------------------------------
# ['medellin', 'inauguran', 'tunel', 'bogota', 'semaforo', 'chiste', 'cuenta', 'solo']
# ['amor', 'bebida', 'desprecio', 'sobriedad']
# ['consultas', 'semana', 'comienzo', 'enunciado', 'escribe', '«', 'll', '»', '«', 'll', '»', 'si', 'palabra', 'empieza', '«', 'll', '»', 'escribe']
# ['dijeron', 'sol', 'puedo', 'mas', 'desacuerdo']
# ['comparten', 'enseñan', 'borran', 'vez', 'termina', 'relacion']
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:04:30
# -------------------------------------------
# ('mas', 9)
# ('años', 7)
# ('hoy', 6)
# ('dia', 5)
# ('q', 5)
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:05:00
# -------------------------------------------
# Tweets del batch: 102
#
# -------------------------------------------
# Time: 2019-08-15 15:05:00
# -------------------------------------------
# Tweets total (medio minuto rolling): 102
#
# -------------------------------------------
# Time: 2019-08-15 15:05:00
# -------------------------------------------
# Que hermoso despertarme asi😍😍
# -hola vos podes creeer qu..
# - hola , déjame adivinar , dólar a 62,macri gato,Cristina se roba todo , aumenta todo ,… https://t.co/o5N8lP2HZr
# RT @elcitizen: A Maduro le conviene fabricar un conflicto con Colombia para nuclear la FAN en torno a el. Padrino pica adelante apoyando a…
# @Luqipasivo1 Cuando quieras
# @ReporTAxiLeon Es ese de las gráficas
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:05:00
# -------------------------------------------
# hermoso despertarme asi
# hola vos podes creer qu hola dejame adivinar dolar macri gatocristina roba aumenta
# maduro conviene fabricar conflicto colombia nuclear fan torno padrino pica adelante apoyando
# quieras
# graficas
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:05:00
# -------------------------------------------
# ['hermoso', 'despertarme', 'asi']
# ['hola', 'vos', 'podes', 'creer', 'qu', 'hola', 'dejame', 'adivinar', 'dolar', 'macri', 'gatocristina', 'roba', 'aumenta']
# ['maduro', 'conviene', 'fabricar', 'conflicto', 'colombia', 'nuclear', 'fan', 'torno', 'padrino', 'pica', 'adelante', 'apoyando']
# ['quieras']
# ['graficas']
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:05:00
# -------------------------------------------
# ('mas', 6)
# ('￼', 5)
# ('si', 5)
# ('grito', 4)
# ('tan', 4)
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:05:30
# -------------------------------------------
# Tweets del batch: 94
#
# -------------------------------------------
# Time: 2019-08-15 15:05:30
# -------------------------------------------
# Tweets total (medio minuto rolling): 94
#
# -------------------------------------------
# Time: 2019-08-15 15:05:30
# -------------------------------------------
# RT @eldestapeweb: Elecciones 2019: en TN mostraron cuáles son las causas judiciales que afectan a Macri y sus funcionarios https://t.co/9S4…
# RT @Toni_Padilla: Menuda maravilla. El Union Berlin debuta en la Bundesliga y lo celebra en su primer partido en casa imprimendo la foto de…
# RT @Seviempleo: BOP: Convocatoria para la provisión de una plaza de técnica/o medio OPEM en el @Ayto_algaba , página 18 https://t.co/PYXA9T…
# RT @mwfc_oficial: En las vísperas de nuestro cumpleaños, queremos compartir con ustedes un gran regalo para todos!
#
# 🏡 Les presentamos nuest…
# @zezar48 @ManzanoDante @TVale2012 Cuanto te pagan por provocar? Estas dando por hecho que me paso. Soy pequeña empr… https://t.co/vxPNRx634s
# ...
# -------------------------------------------
# Time: 2019-08-15 15:05:30
# -------------------------------------------
# elecciones tn mostraron cuales causas judiciales afectan macri funcionarios
# menuda maravilla union berlin debuta bundesliga celebra primer partido casa imprimendo foto
# bop convocatoria provision plaza tecnicao medio opem pagina
# visperas cumpleaños queremos compartir ustedes gran regalo presentamos nuest
# cuanto pagan provocar dando hecho paso pequeña empr
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:05:30
# -------------------------------------------
# ['elecciones', 'tn', 'mostraron', 'cuales', 'causas', 'judiciales', 'afectan', 'macri', 'funcionarios']
# ['menuda', 'maravilla', 'union', 'berlin', 'debuta', 'bundesliga', 'celebra', 'primer', 'partido', 'casa', 'imprimendo', 'foto']
# ['bop', 'convocatoria', 'provision', 'plaza', 'tecnicao', 'medio', 'opem', 'pagina']
# ['visperas', 'cumpleaños', 'queremos', 'compartir', 'ustedes', 'gran', 'regalo', 'presentamos', 'nuest']
# ['cuanto', 'pagan', 'provocar', 'dando', 'hecho', 'paso', 'pequeña', 'empr']
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:05:30
# -------------------------------------------
# ('si', 7)
# ('mas', 7)
# ('años', 7)
# ('gente', 4)
# ('bien', 4)
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:06:00
# -------------------------------------------
# Tweets del batch: 97
#
# -------------------------------------------
# Time: 2019-08-15 15:06:00
# -------------------------------------------
# Tweets total (medio minuto rolling): 97
#
# -------------------------------------------
# Time: 2019-08-15 15:06:00
# -------------------------------------------
# RT @yazmint01039454: Estoy pensando ceria mnete en dar cerbicio creen q pege mi negocio
# @sunchalensis @hombreenlacaja Ahora te cuento es uno que se caso subió todo acá bombos platillos le duro lo que un… https://t.co/w8tGl9AXT5
# RT @ExpresionChaca: ¡No pedimos nada, queremos ver a Chaca! 🇾🇪
#
# La alegría de que comience una nueva ilusión no es la misma. Desde las 21.0…
# @oscarortizsv BASURA DEL FMLN QUE DESAPAREZCAN YA .... ESPERO CON ANSIAS EL 2021 PARA VERLOS LLORAR CORRUPTOS
# RT @elespectador: #LoMásLeído en Bogotá: El Bambú: primera mansión ilegal que derriban en los cerros de Bogotá. https://t.co/SbfUwgoLs5 htt…
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:06:00
# -------------------------------------------
# pensando ceria mnete dar cerbicio creen q pege negocio
# ahora cuento caso subio aca bombos platillos duro
# pedimos queremos ver chaca 🇾🇪 alegria comience nueva ilusion misma
# basura fmln desaparezcan espero ansias verlos llorar corruptos
# lomasleido bogota bambu primera mansion ilegal derriban cerros bogota htt
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:06:00
# -------------------------------------------
# ['pensando', 'ceria', 'mnete', 'dar', 'cerbicio', 'creen', 'q', 'pege', 'negocio']
# ['ahora', 'cuento', 'caso', 'subio', 'aca', 'bombos', 'platillos', 'duro']
# ['pedimos', 'queremos', 'ver', 'chaca', '🇾🇪', 'alegria', 'comience', 'nueva', 'ilusion', 'misma']
# ['basura', 'fmln', 'desaparezcan', 'espero', 'ansias', 'verlos', 'llorar', 'corruptos']
# ['lomasleido', 'bogota', 'bambu', 'primera', 'mansion', 'ilegal', 'derriban', 'cerros', 'bogota', 'htt']
# ...
#
# -------------------------------------------
# Time: 2019-08-15 15:06:00
# -------------------------------------------
# ('mas', 9)
# ('si', 9)
# ('vida', 6)
# ('años', 5)
# ('van', 4)
# ...
#
# !!!!!!!!!!!!!!!!!!!!STOPPED!!!!!!!!!!!!!!!!!!!!

# %% [markdown]
# Con esta primera prueba de uso de Spark Streaming, conectamos con Kafka recogiendo los datos de twitter que están llegando al sistema, y hacemos unas primeras pruebas de preprocesado de los textos, y les aplicamos ciertos análisis o funciones como ver en cada batch las palabrás más repetidas o sacar el recuento de tweets de cada batch procesado.
#
# Vamos a seguir avanzando en el streaming por el uso de Structured Streaming, que es más moderno y nos permite usar los datos recogidos en streaming como dataframes, lo cual está más alineado con el resto de trabajo realizado ya que estamos trabajando con dataframes a lo largo de todo el desarrollo realizado.
